# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3,include_bias=True)
X_df = pd.DataFrame(X.reshape(-1, 1))
X_poly = poly.fit_transform(X_df)
X_poly
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 2.00400802e-03, 4.01604813e-06, 8.04819264e-09],
#        [1.00000000e+00, 4.00801603e-03, 1.60641925e-05, 6.43855411e-08],
#        ...,
#        [1.00000000e+00, 9.95991984e-01, 9.92000032e-01, 9.88024080e-01],
#        [1.00000000e+00, 9.97995992e-01, 9.95996000e-01, 9.94000016e-01],
#        [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_poly, Y, test_size=0.1,random_state=3)

# %%
class Linear_Regression():

    def __init__(self, learning_rate, iterations):
        self.learning_rate = learning_rate
        self.iterations = iterations

    def fit(self,X,Y):
        self.m, self.n = X.shape

        self.w = np.zeros(self.n)
        self.X = X
        self.Y = Y

        for i in range(self.iterations):
            self.update_weights()

    def update_weights(self,):

        Y_prediction = self.predict(self.X)

        dw = (-2*(self.X.T).dot(self.Y-Y_prediction))/self.m
        
        self.w = self.w - self.learning_rate*dw

    def predict(self,X):

        return X.dot(self.w)

# %%
ALL_MAE=[]
LEARNING_RATE=[]
ALL_Learning_rate = list(np.arange(.01,.3,.04))

for m in range(len(ALL_Learning_rate)):
    model=Linear_Regression(learning_rate=ALL_Learning_rate[m],iterations=1000)
    model.fit(X_train,y_train)
    Y_test_predict = model.predict(X_test)
    Total_sum=0
    n=len(y_test)
    for i in range(n):
        Total_sum += abs(Y_test_predict[i] - y_test[i])
  
        MAE = Total_sum/n
        print(f'Mean Absolute Error is {MAE} and learning rate is {model.learning_rate} ')

    ALL_MAE.append(MAE)
    LEARNING_RATE.append(model.learning_rate)
# Out:
# Mean Absolute Error is 0.0007414219671949352 and learning rate is 0.01
# Mean Absolute Error is 0.0008583536288312277 and learning rate is 0.01
# Mean Absolute Error is 0.0014595962922526317 and learning rate is 0.01
# Mean Absolute Error is 0.0021833493548074736 and learning rate is 0.01
# Mean Absolute Error is 0.002509536216846071 and learning rate is 0.01
# Mean Absolute Error is 0.00281962158278527 and learning rate is 0.01
# Mean Absolute Error is 0.003091312737129961 and learning rate is 0.01
# Mean Absolute Error is 0.003527760281558501 and learning rate is 0.01
# Mean Absolute Error is 0.0036470841026234146 and learning rate is 0.01
# Mean Absolute Error is 0.0037608196258837865 and learning rate is 0.01
# Mean Absolute Error is 0.004306715626452267 and learning rate is 0.01
# Mean Absolute Error is 0.004518978463948112 and learning rate is 0.01
# Mean Absolute Error is 0.004704643077149804 and learning rate is 0.01
# ...

# %%
plt.plot(LEARNING_RATE, ALL_MAE)
plt.xlabel("learning rate")
plt.ylabel("Mean Absolute Error")
plt.show()

# %%
model=Linear_Regression(learning_rate=0.1,iterations=1000)
model.fit(X_train,y_train)
Y_test_predict = model.predict(X_test)
model.w
# Out:
# array([ 0.81800333,  0.29057346,  0.01694517, -0.16793627])

# %%
Total_sum=0
n=len(y_test)
for i in range(n):
    Total_sum += abs(Y_test_predict[i] - y_test[i])
  
    MAE = Total_sum/n
print(f'Mean Absolute Error is {MAE} and learning rate is {model.learning_rate} ')
# Out:
# Mean Absolute Error is 0.02331831598681814 and learning rate is 0.1

# %% [markdown]
# Mean Absolute Error is 0.02331831598681814 and learning rate is 0.1

# %%
x_axis = np.arange(0,1, 0.01)
Predicted = model.w[0] + model.w[1] * x_axis + model.w[2]*x_axis**2  + model.w[3]*x_axis**3 # + model.w[4]*x_axis**4 #+ model.w[5]*x_axis**5

# %%
plt.scatter(X_test[:,1], Y_test_predict,label='Predicted')
plt.scatter(X_test[:,1], y_test, color='red',label='Actual')
plt.title('3rd Order Polynomial fit')
plt.ylabel('Y_Values')
plt.xlabel('X_Values')
plt.legend()
plt.show()

# %%
plt.scatter(X, Y, color='green',label='Actual')
plt.plot(x_axis, Predicted,color='red',label='fitted')
plt.title('3rd Order Polynomial fit')
plt.ylabel('Y_Values')
plt.xlabel('X_Values')
plt.legend()
plt.show()

# %% [markdown]
# # Linear regression with Gaussian Basis function

# %%
def gaussian_basis(x, mu, sigma=.2):
        return np.exp(-((mu-x)**2)/sigma**2)
#phi_X=[]
all_phi_X=[]
mu=np.arange(.1,1, 0.2)
    
for i in range(len(mu)):
    Phi_X = gaussian_basis((X_poly[:,1]),mu[i],sigma=.2)
    
    #all_phi_X.append([Phi_X]) 
    all_phi_X.insert(i,Phi_X)
all_phi_X = pd.DataFrame(all_phi_X).T
all_phi_X
# Out:
#                 0         1         2         3             4
# 0    7.788008e-01  0.105399  0.001930  0.000005  1.605228e-09
# 1    7.865646e-01  0.108605  0.002029  0.000005  1.756540e-09
# 2    7.942464e-01  0.111885  0.002133  0.000006  1.921728e-09
# 3    8.018422e-01  0.115242  0.002242  0.000006  2.102030e-09
# 4    8.093480e-01  0.118675  0.002355  0.000006  2.298785e-09
# ..            ...       ...       ...       ...           ...
# 495  2.298785e-09  0.000006  0.002355  0.118675  8.093480e-01
# 496  2.102030e-09  0.000006  0.002242  0.115242  8.018422e-01
# 497  1.921728e-09  0.000006  0.002133  0.111885  7.942464e-01
# 498  1.756540e-09  0.000005  0.002029  0.108605  7.865646e-01
# 499  1.605228e-09  0.000005  0.001930  0.105399  7.788008e-01
#
# [500 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train_2, X_test_2, y_train, y_test = train_test_split(all_phi_X, Y, test_size=0.1,random_state=3)

# %%
w = np.linalg.inv(X_train_2.T @ X_train_2) @ X_train_2.T @ y_train
w
# Out:
# 0    0.781296
# 1    0.282958
# 2    0.718939
# 3    0.359369
# 4    0.870897
# dtype: float64

# %%
def predict(w,X):
    return X.dot(w)

Y_test_predict = predict(w,X_test_2)

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_test, Y_test_predict)
print(f'Mean Absolute Error is {MAE} ')
# Out:
# Mean Absolute Error is 0.04459117804003772

# %% [markdown]
# Mean Absolute Error is 0.04459117804003772

# %%
plt.scatter(X_test[:,1], Y_test_predict,label='Predicted')
plt.scatter(X_test[:,1], y_test, color='red',label='Actual')
plt.title('Guassian fit')
plt.ylabel('Y_Values')
plt.xlabel('X_Values')
plt.legend()
plt.show()
